# %% [markdown]
# #                                                         *READING(CSV,JSON,PARQUET)FILE*

# %% [markdown]
# # *IMPORTING NECESSARY LIBRARIES*

# %%
pip install pandas
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install pyarrow
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install numpy
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd

# %%
import numpy as np

# %%
import os

# %% [markdown]
# # *CSV FILE READING*

# %% [markdown]
# # *FILE 1*

# %%
csv_path1="C:\\Users\\Aumuthakaviya\\Documents\\amutha\\customers-100.csv"

# %% [markdown]
# # *READ DATASET*

# %%
df_csv1=pd.read_csv(csv_path1)

# %%
df_csv1
# Out:
#     Index      Customer Id First Name Last Name  \
# 0       1  DD37Cf93aecA6Dc     Sheryl    Baxter
# 1       2  1Ef7b82A4CAAD10    Preston    Lozano
# 2       3  6F94879bDAfE5a6        Roy     Berry
# 3       4  5Cef8BFA16c5e3c      Linda     Olsen
# 4       5  053d585Ab6b3159     Joanna    Bender
# ..    ...              ...        ...       ...
# 95     96  cb8E23e48d22Eae       Karl     Greer
# 96     97  CeD220bdAaCfaDf       Lynn  Atkinson
# 97     98  28CDbC0dFe4b1Db       Fred    Guerra
# 98     99  c23d1D9EE8DEB0A     Yvonne    Farmer
# 99    100  2354a0E336A91A1   Clarence    Haynes
#
#                             Company               City  \
# 0                   Rasmussen Group       East Leonard
# 1                       Vega-Gentry  East Jimmychester
# 2                     Murillo-Perry      Isabelborough
# 3   Dominguez, Mcmillan and Donovan         Bensonview
# 4          Martin, Lang and Andrade     West Priscilla
# ...

# %% [markdown]
# # *FILE 2*

# %%
csv_path2="C:\\Users\\Aumuthakaviya\\Documents\\amutha\\customers-1000.csv"

# %% [markdown]
# # *READ DATASET*

# %%
df_csv2=pd.read_csv(csv_path2)

# %%
df_csv2
# Out:
#      Index      Customer Id First Name Last Name                      Company  \
# 0        1  dE014d010c7ab0c     Andrew   Goodman                Stewart-Flynn
# 1        2  2B54172c8b65eC3      Alvin      Lane  Terry, Proctor and Lawrence
# 2        3  d794Dd48988d2ac      Jenna   Harding                 Bailey Group
# 3        4  3b3Aa4aCc68f3Be   Fernando      Ford                 Moss-Maxwell
# 4        5  D60df62ad2ae41E       Kara     Woods              Mccarthy-Kelley
# ..     ...              ...        ...       ...                          ...
# 995    996  FbcCaF483aFaFAE      Diana    Monroe                  Bass-Wilson
# 996    997  979c4D58Ae9a9cc      Jerry   Morales                   Pratt-King
# 997    998  D0DcF6a4BcefCc8     Tracie     Floyd     Holt, Wilson and Shields
# 998    999  90EE9CbbDa374E9       Paul    Barnes     Brown, Oliver and Haynes
# 999   1000  51732B5b2328015    Dominic     Duran                   Durham LLC
#
# ...

# %% [markdown]
# # *FILE 3*

# %%
csv_path3="C:\\Users\\Aumuthakaviya\\Documents\\amutha\\customers-10000.csv"

# %% [markdown]
# # *READ DATASET*

# %%
df_csv3=pd.read_csv(csv_path3)

# %%
df_csv3
# Out:
#       Index      Customer Id First Name   Last Name                   Company  \
# 0         1  EB54EF1154C3A78    Heather    Callahan              Mosley-David
# 1         2  10dAcafEBbA5FcA   Kristina     Ferrell  Horn, Shepard and Watson
# 2         3  67DAB15Ebe4BE4a     Briana    Andersen               Irwin-Oneal
# 3         4  6d350C5E5eDB4EE      Patty       Ponce          Richardson Group
# 4         5  5820deAdCF23EFe   Kathleen   Mccormick              Carson-Burch
# ...     ...              ...        ...         ...                       ...
# 9995   9996  DD0caa06ebf217c     Meghan       Cline            Richardson LLC
# 9996   9997  C1C62ff90D0AfED   Jeremiah        Pena               Hodge-Nixon
# 9997   9998  2EfAa6Fe435A7DA      Peggy         Key                  Vang LLC
# 9998   9999  5dB06C3Fab5CCCb       Evan    Humphrey                 Gould Ltd
# 9999  10000  9903e8fF4D8Ff0F    Melissa  Montgomery              Burns-Holden
#
# ...

# %% [markdown]
# # *JSON FILE READING*

# %%
import json 
import pandas as pd

# %% [markdown]
# # *FILE 1*

# %%
json_path1="C:\\Users\\Aumuthakaviya\\Documents\\amutha\\sample1 (1).json"

# %% [markdown]
# # *READING THE DATASET*

# %%
with open(json_path1,"r") as f:
    raw_data1=json.load(f)

# %%
df_json1=pd.json_normalize(raw_data1)

# %%
df_json1
# Out:
#    name  age         city  married                            hobbies  \
# 0  John   25  Sampleville    False  [reading, traveling, programming]
#
#     address.street address.city address.postal_code
# 0  123 Main Street  Sample City               12345

# %% [markdown]
# # *FILE 2*

# %%
json_path2="C:\\Users\\Aumuthakaviya\\Documents\\amutha\\sample2.json"

# %% [markdown]
# # *READING THE DATASET*

# %%
with open(json_path2,"r") as f:
    raw_data2=json.load(f)

# %%
df_json2=pd.json_normalize(raw_data2)

# %%
df_json2
# Out:
#   firstName lastName gender  age                                phoneNumbers  \
# 0       Joe  Jackson   male   28  [{'type': 'home', 'number': '7349282382'}]
#
#   address.streetAddress address.city address.state
# 0                   101    San Diego            CA

# %% [markdown]
# # *FILE 3*

# %%
json_path3="C:\\Users\\Aumuthakaviya\\Documents\\amutha\\airports.json"

# %% [markdown]
# # *READING THE DATASET*

# %%
with open(json_path3,"r") as f:
    raw_data3=json.load(f)

# %%
df_json2
# Out:
#   firstName lastName gender  age                                phoneNumbers  \
# 0       Joe  Jackson   male   28  [{'type': 'home', 'number': '7349282382'}]
#
#   address.streetAddress address.city address.state
# 0                   101    San Diego            CA

# %% [markdown]
# # *PARQUET FILE READING*

# %% [markdown]
# # *FILE 1*

# %%
parquet_path1="C:\\Users\\Aumuthakaviya\\Documents\\amutha\\userdata.parquet"

# %% [markdown]
# # *READING THE DATASET*

# %%
df_parquet1=pd.read_parquet(parquet_path1,engine="pyarrow")

# %%
df_parquet1
# Out:
#       registration_dttm    id first_name last_name                     email  \
# 0   2016-02-03 07:55:29     1     Amanda    Jordan          ajordan0@com.com
# 1   2016-02-03 17:04:03     2     Albert   Freeman           afreeman1@is.gd
# 2   2016-02-03 01:09:31     3     Evelyn    Morgan   emorgan2@altervista.org
# 3   2016-02-03 00:36:21     4     Denise     Riley          driley3@gmpg.org
# 4   2016-02-03 05:05:31     5     Carlos     Burns  cburns4@miitbeian.gov.cn
# ..                  ...   ...        ...       ...                       ...
# 995 2016-02-03 10:30:59   996     Dennis    Harris      dharrisrn@eepurl.com
# 996 2016-02-03 17:16:53   997     Gloria  Hamilton    ghamiltonro@rambler.ru
# 997 2016-02-03 05:02:20   998      Nancy    Morris         nmorrisrp@ask.com
# 998 2016-02-03 02:41:32   999      Annie   Daniels    adanielsrq@squidoo.com
# 999 2016-02-03 09:52:18  1000      Julie     Meyer       jmeyerrr@flavors.me
#
# ...

# %% [markdown]
# # *FILE 2*

# %%
parquet_path2="C:\\Users\\Aumuthakaviya\\Documents\\amutha\\iris.parquet"

# %% [markdown]
# # *READING THE DATASET*

# %%
df_parquet2=pd.read_parquet(parquet_path2,engine="pyarrow")

# %%
df_parquet2
# Out:
#      sepal.length  sepal.width  petal.length  petal.width    variety
# 0             5.1          3.5           1.4          0.2     Setosa
# 1             4.9          3.0           1.4          0.2     Setosa
# 2             4.7          3.2           1.3          0.2     Setosa
# 3             4.6          3.1           1.5          0.2     Setosa
# 4             5.0          3.6           1.4          0.2     Setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  Virginica
# 146           6.3          2.5           5.0          1.9  Virginica
# 147           6.5          3.0           5.2          2.0  Virginica
# 148           6.2          3.4           5.4          2.3  Virginica
# 149           5.9          3.0           5.1          1.8  Virginica
#
# [150 rows x 5 columns]

# %% [markdown]
# # *FILE 3*

# %%
parquet_path3="C:\\Users\\Aumuthakaviya\\Documents\\amutha\\userdata.parquet"

# %% [markdown]
# # *READING THE DATASET*

# %%
df_parquet3=pd.read_parquet(parquet_path3,engine="pyarrow")

# %%
df_parquet3
# Out:
#       registration_dttm    id first_name last_name                     email  \
# 0   2016-02-03 07:55:29     1     Amanda    Jordan          ajordan0@com.com
# 1   2016-02-03 17:04:03     2     Albert   Freeman           afreeman1@is.gd
# 2   2016-02-03 01:09:31     3     Evelyn    Morgan   emorgan2@altervista.org
# 3   2016-02-03 00:36:21     4     Denise     Riley          driley3@gmpg.org
# 4   2016-02-03 05:05:31     5     Carlos     Burns  cburns4@miitbeian.gov.cn
# ..                  ...   ...        ...       ...                       ...
# 995 2016-02-03 10:30:59   996     Dennis    Harris      dharrisrn@eepurl.com
# 996 2016-02-03 17:16:53   997     Gloria  Hamilton    ghamiltonro@rambler.ru
# 997 2016-02-03 05:02:20   998      Nancy    Morris         nmorrisrp@ask.com
# 998 2016-02-03 02:41:32   999      Annie   Daniels    adanielsrq@squidoo.com
# 999 2016-02-03 09:52:18  1000      Julie     Meyer       jmeyerrr@flavors.me
#
# ...
